# %%
#import sys
#!{sys.executable} -m pip install opentrons

import opentrons
import opentrons.execute
from opentrons import protocol_api
# Out:
# Loading json containers...
# Json container file load complete, listing database
# Found 58 containers to add. Starting migration...
# migrating alum-block-pcr-strips from json to database
# CONTAINER: alum-block-pcr-strips, (x=0.00, y=0.00, z=0.00)
# migrating trough-1row-test from json to database
# CONTAINER: trough-1row-test, (x=0.00, y=0.00, z=0.00)
# migrating tube-rack-80well from json to database
# CONTAINER: tube-rack-80well, (x=0.00, y=0.00, z=0.00)
# migrating 96-PCR-flat from json to database
# CONTAINER: 96-PCR-flat, (x=0.00, y=0.00, z=0.00)
# migrating e-gelgol from json to database
# CONTAINER: e-gelgol, (x=0.00, y=0.00, z=0.00)
# migrating temperature-plate from json to database
# CONTAINER: temperature-plate, (x=0.00, y=0.00, z=97.00)
# migrating tiprack-200ul from json to database
# CONTAINER: tiprack-200ul, (x=0.00, y=0.00, z=0.00)
# migrating opentrons-tiprack-300ul from json to database
# CONTAINER: opentrons-tiprack-300ul, (x=0.00, y=0.00, z=0.00)
# migrating 384-plate from json to database
# CONTAINER: 384-plate, (x=0.00, y=0.00, z=0.00)
# migrating 48-vial-plate from json to database
# CONTAINER: 48-vial-plate, (x=0.00, y=0.00, z=0.00)
# migrating opentrons-tiprack-1000ul from json to database
# CONTAINER: opentrons-tiprack-1000ul, (x=0.00, y=0.00, z=0.00)
# migrating 48-well-plate from json to database
# CONTAINER: 48-well-plate, (x=0.00, y=0.00, z=0.00)
# migrating point from json to database
# CONTAINER: point, (x=0.00, y=0.00, z=0.00)
# migrating small_vial_rack_16x45 from json to database
# CONTAINER: small_vial_rack_16x45, (x=0.00, y=0.00, z=0.00)
# migrating trough-12row from json to database
# CONTAINER: trough-12row, (x=0.00, y=0.00, z=0.00)
# migrating wheaton_vial_rack from json to database
# CONTAINER: wheaton_vial_rack, (x=0.00, y=0.00, z=0.00)
# migrating 96-flat from json to database
# CONTAINER: 96-flat, (x=0.00, y=0.00, z=0.00)
# migrating opentrons-tuberack-2ml-eppendorf from json to database
# CONTAINER: opentrons-tuberack-2ml-eppendorf, (x=0.00, y=0.00, z=0.00)
# migrating magdeck from json to database
# CONTAINER: magdeck, (x=0.00, y=0.00, z=0.00)
# migrating biorad-hardshell-96-PCR from json to database
# CONTAINER: biorad-hardshell-96-PCR, (x=0.00, y=0.00, z=0.00)
# migrating opentrons-tuberack-1.5ml-eppendorf from json to database
# CONTAINER: opentrons-tuberack-1.5ml-eppendorf, (x=0.00, y=0.00, z=0.00)
# migrating tiprack-10ul-H from json to database
# CONTAINER: tiprack-10ul-H, (x=0.00, y=0.00, z=0.00)
# migrating tube-rack-2ml from json to database
# CONTAINER: tube-rack-2ml, (x=0.00, y=0.00, z=52.00)
# migrating 24-well-plate from json to database
# CONTAINER: 24-well-plate, (x=0.00, y=0.00, z=0.00)
# migrating tube-rack-.75ml from json to database
# CONTAINER: tube-rack-.75ml, (x=0.00, y=0.00, z=55.00)
# migrating T75-flask from json to database
# CONTAINER: T75-flask, (x=0.00, y=0.00, z=0.00)
# migrating rigaku-compact-crystallization-plate from json to database
# CONTAINER: rigaku-compact-crystallization-plate, (x=0.00, y=0.00, z=0.00)
# migrating opentrons-aluminum-block-PCR-strips-200ul from json to database
# CONTAINER: opentrons-aluminum-block-PCR-strips-200ul, (x=0.00, y=0.00, z=0.00)
# migrating 6-well-plate from json to database
# CONTAINER: 6-well-plate, (x=0.00, y=0.00, z=0.00)
# migrating opentrons-tuberack-15_50ml from json to database
# CONTAINER: opentrons-tuberack-15_50ml, (x=0.00, y=0.00, z=0.00)
# migrating hampton-1ml-deep-block from json to database
# CONTAINER: hampton-1ml-deep-block, (x=0.00, y=0.00, z=0.00)
# migrating fixed-trash from json to database
# CONTAINER: fixed-trash, (x=0.00, y=0.00, z=0.00)
# migrating tiprack-1000ul from json to database
# CONTAINER: tiprack-1000ul, (x=0.00, y=0.00, z=0.00)
# migrating opentrons-aluminum-block-96-PCR-plate from json to database
# CONTAINER: opentrons-aluminum-block-96-PCR-plate, (x=0.00, y=0.00, z=0.00)
# migrating trough-1row-25ml from json to database
# CONTAINER: trough-1row-25ml, (x=0.00, y=0.00, z=0.00)
# migrating 12-well-plate from json to database
# CONTAINER: 12-well-plate, (x=0.00, y=0.00, z=0.00)
# migrating tube-rack-2ml-9x9 from json to database
# CONTAINER: tube-rack-2ml-9x9, (x=0.00, y=0.00, z=0.00)
# migrating tall-fixed-trash from json to database
# CONTAINER: tall-fixed-trash, (x=0.00, y=0.00, z=0.00)
# migrating opentrons-tuberack-2ml-screwcap from json to database
# CONTAINER: opentrons-tuberack-2ml-screwcap, (x=0.00, y=0.00, z=0.00)
# migrating trash-box from json to database
# CONTAINER: trash-box, (x=0.00, y=0.00, z=0.00)
# migrating MALDI-plate from json to database
# CONTAINER: MALDI-plate, (x=0.00, y=0.00, z=0.00)
# migrating tiprack-10ul from json to database
# CONTAINER: tiprack-10ul, (x=0.00, y=0.00, z=0.00)
# migrating opentrons-tuberack-15ml from json to database
# CONTAINER: opentrons-tuberack-15ml, (x=0.00, y=0.00, z=0.00)
# migrating tempdeck from json to database
# CONTAINER: tempdeck, (x=0.00, y=0.00, z=0.00)
# migrating 96-well-plate-20mm from json to database
# CONTAINER: 96-well-plate-20mm, (x=0.00, y=0.00, z=0.00)
# migrating 5ml-3x4 from json to database
# CONTAINER: 5ml-3x4, (x=0.00, y=0.00, z=0.00)
# migrating opentrons-tuberack-50ml from json to database
# CONTAINER: opentrons-tuberack-50ml, (x=0.00, y=0.00, z=0.00)
# migrating tube-rack-15_50ml from json to database
# CONTAINER: tube-rack-15_50ml, (x=0.00, y=0.00, z=0.00)
# migrating 96-PCR-tall from json to database
# CONTAINER: 96-PCR-tall, (x=0.00, y=0.00, z=0.00)
# migrating opentrons-aluminum-block-2ml-eppendorf from json to database
# CONTAINER: opentrons-aluminum-block-2ml-eppendorf, (x=0.00, y=0.00, z=0.00)
# migrating T25-flask from json to database
# CONTAINER: T25-flask, (x=0.00, y=0.00, z=0.00)
# migrating tube-rack-5ml-96 from json to database
# CONTAINER: tube-rack-5ml-96, (x=0.00, y=0.00, z=0.00)
# migrating PCR-strip-tall from json to database
# CONTAINER: PCR-strip-tall, (x=0.00, y=0.00, z=0.00)
# migrating trough-12row-short from json to database
# CONTAINER: trough-12row-short, (x=0.00, y=0.00, z=0.00)
# migrating opentrons-aluminum-block-2ml-screwcap from json to database
# CONTAINER: opentrons-aluminum-block-2ml-screwcap, (x=0.00, y=0.00, z=0.00)
# migrating 96-deep-well from json to database
# CONTAINER: 96-deep-well, (x=0.00, y=0.00, z=0.00)
# migrating opentrons-tiprack-10ul from json to database
# CONTAINER: opentrons-tiprack-10ul, (x=0.00, y=0.00, z=0.00)
# C:\Users\jrm120\.opentrons\deck_calibration.json not found. Loading defaults
# migrating 24-vial-rack from json to database
# CONTAINER: 24-vial-rack, (x=0.00, y=0.00, z=0.00)
# Database migration complete!
# C:\Users\jrm120\.opentrons\robot_settings.json not found. Loading defaults

# %% [markdown]
# # Serial Dilution

# %%
from opentrons import protocol_api

# %%
metadata = {
    'apiLevel': '2.13',
    'protocolName': 'Serial Dilution Tutorial',
    'description': '''This protocol is the outcome of following the
                   Python Protocol API Tutorial located at
                   https://docs.opentrons.com/v2/tutorial.html. It takes a
                   solution and progressively dilutes it by transferring it
                   stepwise across a plate.''',
    'author': 'New API User'
    }

# %%
from opentrons import simulate
metadata = {'apiLevel': '2.7'}
protocol = simulate.get_protocol_api('2.7')
plate = protocol.load_labware('corning_96_wellplate_360ul_flat', 1)
tiprack_1 = protocol.load_labware('opentrons_96_tiprack_300ul', 2)
p300 = protocol.load_instrument('p300_single_gen2', 'right',
tip_racks=[tiprack_1])
reservoir = protocol.load_labware('usascientific_12_reservoir_22ml', 3)



metadata = {'apiLevel': '2.7'}
def run(protocol: protocol_api.ProtocolContext):
    tips = protocol.load_labware('opentrons_96_tiprack_300ul', 1)
    reservoir = protocol.load_labware('nest_12_reservoir_15ml', 2)
    plate = protocol.load_labware('nest_96_wellplate_200ul_flat', 3)
    p300 = protocol.load_instrument('p300_multi_gen2', 'left', tip_racks=[tips])
    row = plate.rows()[0]
    p300.transfer(100, reservoir['A1'], row[1:], new_tip='once')
    p300.transfer(200, reservoir['A2'], row[0])
    p300.transfer(100, row[:11], row[1:], mix_after=(3, 50))

    p300.pick_up_tip()
    p300.aspirate(100, row[11])
    p300.drop_tip()
# Out:
# C:\Users\Joshua\.opentrons\robot_settings.json not found. Loading defaults
# C:\Users\Joshua\.opentrons\deck_calibration.json not found. Loading defaults

# %%
from opentrons import simulate
metadata = {'apiLevel': '2.0'}
protocol = simulate.get_protocol_api('2.0')
plate = protocol.load_labware('corning_96_wellplate_360ul_flat', 1)
tiprack_1 = protocol.load_labware('opentrons_96_tiprack_300ul', 2)
p300 = protocol.load_instrument('p300_multi_gen2', 'right',
tip_racks=[tiprack_1])
reservoir = protocol.load_labware('usascientific_12_reservoir_22ml', 3)

row = plate.rows()[0]
p300.pick_up_tip()
p300.transfer(100, reservoir['A1'], row[1:], new_tip='never')
p300.blow_out()
p300.transfer(200, reservoir['A2'], row[0], new_tip='never')
p300.blow_out()
p300.transfer(100, row[:10], row[1:11], mix_after=(3, 50), new_tip='never', blow_out=True)
p300.aspirate(100, row[10])
p300.drop_tip()        

for line in protocol.commands():
    print(line)
# Out:
# C:\Users\jrm120\.opentrons\deck_calibration.json not found. Loading defaults
# C:\Users\jrm120\.opentrons\robot_settings.json not found. Loading defaults
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 2
# Transferring 100.0 from A1 of USA Scientific 12 Well Reservoir 22 mL on 3 to A2 of Corning 96 Well Plate 360 µL Flat on 1
# Aspirating 100.0 uL from A1 of USA Scientific 12 Well Reservoir 22 mL on 3 at 1.0 speed
# Dispensing 100.0 uL into A2 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Aspirating 100.0 uL from A1 of USA Scientific 12 Well Reservoir 22 mL on 3 at 1.0 speed
# Dispensing 100.0 uL into A3 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Aspirating 100.0 uL from A1 of USA Scientific 12 Well Reservoir 22 mL on 3 at 1.0 speed
# Dispensing 100.0 uL into A4 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Aspirating 100.0 uL from A1 of USA Scientific 12 Well Reservoir 22 mL on 3 at 1.0 speed
# Dispensing 100.0 uL into A5 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Aspirating 100.0 uL from A1 of USA Scientific 12 Well Reservoir 22 mL on 3 at 1.0 speed
# Dispensing 100.0 uL into A6 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Aspirating 100.0 uL from A1 of USA Scientific 12 Well Reservoir 22 mL on 3 at 1.0 speed
# Dispensing 100.0 uL into A7 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Aspirating 100.0 uL from A1 of USA Scientific 12 Well Reservoir 22 mL on 3 at 1.0 speed
# Dispensing 100.0 uL into A8 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Aspirating 100.0 uL from A1 of USA Scientific 12 Well Reservoir 22 mL on 3 at 1.0 speed
# Dispensing 100.0 uL into A9 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Aspirating 100.0 uL from A1 of USA Scientific 12 Well Reservoir 22 mL on 3 at 1.0 speed
# Dispensing 100.0 uL into A10 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Aspirating 100.0 uL from A1 of USA Scientific 12 Well Reservoir 22 mL on 3 at 1.0 speed
# Dispensing 100.0 uL into A11 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Aspirating 100.0 uL from A1 of USA Scientific 12 Well Reservoir 22 mL on 3 at 1.0 speed
# Dispensing 100.0 uL into A12 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Transferring 200.0 from A2 of USA Scientific 12 Well Reservoir 22 mL on 3 to A1 of Corning 96 Well Plate 360 µL Flat on 1
# Aspirating 200.0 uL from A2 of USA Scientific 12 Well Reservoir 22 mL on 3 at 1.0 speed
# Dispensing 200.0 uL into A1 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Transferring 100.0 from A1 of Corning 96 Well Plate 360 µL Flat on 1 to A2 of Corning 96 Well Plate 360 µL Flat on 1
# Aspirating 100.0 uL from A1 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dispensing 100.0 uL into A2 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Mixing 3 times with a volume of 50.0 ul
# Aspirating 50.0 uL from A2 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dispensing 50.0 uL into A2 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Aspirating 50.0 uL from A2 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dispensing 50.0 uL into A2 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Aspirating 50.0 uL from A2 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dispensing 50.0 uL into A2 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 100.0 uL from A2 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dispensing 100.0 uL into A3 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Mixing 3 times with a volume of 50.0 ul
# Aspirating 50.0 uL from A3 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dispensing 50.0 uL into A3 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Aspirating 50.0 uL from A3 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dispensing 50.0 uL into A3 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Aspirating 50.0 uL from A3 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dispensing 50.0 uL into A3 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 100.0 uL from A3 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dispensing 100.0 uL into A4 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Mixing 3 times with a volume of 50.0 ul
# Aspirating 50.0 uL from A4 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dispensing 50.0 uL into A4 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Aspirating 50.0 uL from A4 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dispensing 50.0 uL into A4 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Aspirating 50.0 uL from A4 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dispensing 50.0 uL into A4 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 100.0 uL from A4 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dispensing 100.0 uL into A5 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Mixing 3 times with a volume of 50.0 ul
# Aspirating 50.0 uL from A5 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dispensing 50.0 uL into A5 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Aspirating 50.0 uL from A5 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dispensing 50.0 uL into A5 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Aspirating 50.0 uL from A5 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dispensing 50.0 uL into A5 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 100.0 uL from A5 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dispensing 100.0 uL into A6 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Mixing 3 times with a volume of 50.0 ul
# Aspirating 50.0 uL from A6 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dispensing 50.0 uL into A6 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Aspirating 50.0 uL from A6 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dispensing 50.0 uL into A6 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Aspirating 50.0 uL from A6 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dispensing 50.0 uL into A6 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 100.0 uL from A6 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dispensing 100.0 uL into A7 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Mixing 3 times with a volume of 50.0 ul
# Aspirating 50.0 uL from A7 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dispensing 50.0 uL into A7 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Aspirating 50.0 uL from A7 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dispensing 50.0 uL into A7 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Aspirating 50.0 uL from A7 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dispensing 50.0 uL into A7 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 100.0 uL from A7 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dispensing 100.0 uL into A8 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Mixing 3 times with a volume of 50.0 ul
# Aspirating 50.0 uL from A8 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dispensing 50.0 uL into A8 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Aspirating 50.0 uL from A8 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dispensing 50.0 uL into A8 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Aspirating 50.0 uL from A8 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dispensing 50.0 uL into A8 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 100.0 uL from A8 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dispensing 100.0 uL into A9 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Mixing 3 times with a volume of 50.0 ul
# Aspirating 50.0 uL from A9 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dispensing 50.0 uL into A9 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Aspirating 50.0 uL from A9 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dispensing 50.0 uL into A9 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Aspirating 50.0 uL from A9 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dispensing 50.0 uL into A9 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 100.0 uL from A9 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dispensing 100.0 uL into A10 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Mixing 3 times with a volume of 50.0 ul
# Aspirating 50.0 uL from A10 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dispensing 50.0 uL into A10 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Aspirating 50.0 uL from A10 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dispensing 50.0 uL into A10 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Aspirating 50.0 uL from A10 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dispensing 50.0 uL into A10 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 100.0 uL from A10 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dispensing 100.0 uL into A11 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Mixing 3 times with a volume of 50.0 ul
# Aspirating 50.0 uL from A11 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dispensing 50.0 uL into A11 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Aspirating 50.0 uL from A11 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dispensing 50.0 uL into A11 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Aspirating 50.0 uL from A11 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dispensing 50.0 uL into A11 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Blowing out at A1 of Opentrons Fixed Trash on 12
# Aspirating 100.0 uL from A11 of Corning 96 Well Plate 360 µL Flat on 1 at 1.0 speed
# Dropping tip into A1 of Opentrons Fixed Trash on 12
